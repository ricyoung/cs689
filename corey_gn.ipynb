# %% [markdown]
# <a href="https://colab.research.google.com/github/ricyoung/cs689/blob/master/corey_gn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir /data

# %%
import pandas as pd
import xlrd

# %%
file = '/data/a.xlsx'

# %%
df = pd.read_excel(file, 'Hook3 Simple')

# %%
print(df)
# Out:
#        #  Visible? Starred?  ... Taxonomy B_Hook3_IP B_IgG_R_IP
# 0      1      True    Empty  ...  unknown        137         49
# 1      8      True    Empty  ...  unknown        136         56
# 2     59      True    Empty  ...  unknown        113          0
# 3      4      True    Empty  ...  unknown        108         80
# 4      2      True    Empty  ...  unknown        108         81
# ..   ...       ...      ...  ...      ...        ...        ...
# 610  228      True    Empty  ...  unknown          4         11
# 611  369      True    Empty  ...  unknown          4         11
# 612  375      True    Empty  ...  unknown          4         11
# 613  231      True    Empty  ...  unknown          4         12
# 614  294      True    Empty  ...  unknown          4         12
#
# [615 rows x 11 columns]

# %%
# df1 = df['Identified Proteins (731)']

# %%
# print(df1)
# Out:
# 0      Ubiquitin carboxyl-terminal hydrolase 25 OS=Mu...
# 1                                        sp|K1C10_HUMAN|
# 2                                         sp|K2C1_HUMAN|
# 3                                         sp|K22E_HUMAN|
# 4                                         sp|K1C9_HUMAN|
#                              ...
# 356    Pre-mRNA-processing-splicing factor 8 OS=Mus m...
# 357    Uncharacterized protein OS=Mus musculus OX=100...
# 358    Adiponectin b OS=Mus musculus OX=10090 GN=Adib...
# 359    Uncharacterized protein (Fragment) OS=Mus musc...
# 360    Ig kappa chain V-III region PC 2880/PC 1229 OS...
# Name: Identified Proteins (731), Length: 361, dtype: object

# %%
# if df1.str.contains('GN=').any():
# str.contains('GN=').any()
# Out:
# <class 'str'>

# %%
# dfx = df1[df1.str.contains('GN=')]
# print(dfx)
# Out:
# 0      U5 small nuclear ribonucleoprotein 200 kDa hel...
# 1      Tr-type G domain-containing protein OS=Mus mus...
# 2      Pre-mRNA-processing-splicing factor 8 OS=Mus m...
# 3      Actin, beta OS=Mus musculus OX=10090 GN=Actb P...
# 4      Spna2 protein OS=Mus musculus OX=10090 GN=Spta...
#                              ...
# 591    Kinesin light chain 1 OS=Mus musculus OX=10090...
# 592    Endophilin-A1 OS=Mus musculus OX=10090 GN=Sh3g...
# 593    Adenylyl cyclase-associated protein 1 OS=Mus m...
# 594    Heat shock protein 105 kDa OS=Mus musculus OX=...
# 595    Glucose-6-phosphate isomerase OS=Mus musculus ...
# Name: Identified Proteins (1597), Length: 567, dtype: object

# %%
# print(type(y))
# Out:
# <class 'list'>

# %%
for index, row in df.iterrows(): 
    # print(row[3])
    y = row[3].split(' ')
    # print(y)

    matchers = ['GN=']
    matching = [s for s in y if any(xs in s for xs in matchers)]
    #print(index,matching,  )
    d= ','.join(matching)
    rr = index+1
    e= (rr,d)
   
    print(d)
    #print(e)
  #print(type(e))
# Out:
# GN=Actb
# GN=Dync1h1
# GN=Fam160a2
# GN=Sptan1
# GN=Sptan1
# GN=Sptan1
# GN=Hook3
# GN=Adia
# GN=Sptbn1
# GN=Myh10
# GN=Hspa8
# GN=Gapdh
# GN=Map2
# GN=Tubb2a
# GN=Tubb2b
# GN=Igk
#
# GN=HC
# GN=Tubb4b
# GN=LC
#
# GN=Tubb4a
# GN=Tubb5
# GN=LC
# GN=Igk
# GN=Myh9
# GN=Actc1
# GN=Map1a
# GN=Myo18a
# GN=Tuba1a
# GN=Cltc
# GN=Ighg
# GN=Tuba4a
# GN=Tubb3
#
# GN=Cep170b
# GN=HC
# GN=Cbl
# GN=Actbl2
# GN=Nsf
# GN=Fam160b1
# GN=Dock7
#
# GN=Tspoap1
# GN=Idh3a
#
# GN=Scyl2
# GN=Hip1r
# GN=Dnm1
#
# GN=Map1b
# GN=Dpysl2
# GN=Prrc2a
# GN=HC
# GN=Nptxr
# GN=Igh
# GN=Sptbn2
# GN=Eef1a2
# GN=Hook1
# GN=Epm2aip1
# GN=Myo5a
# GN=Ap2b1
# GN=Uba1
# GN=Dpysl3
# GN=Ighg3
# GN=Rap1gap2
# GN=Eef1a1
# GN=Ckb
# GN=Alb
#
# GN=Btbd11
# GN=Dbn1
# GN=Actn1
# GN=Map6
# GN=Vcp
# GN=Ptn
#
# GN=Actn4
# GN=Hspa2
# GN=Hsp90ab1
# GN=Ctif
# GN=Cct2
# GN=Crmp1
# GN=Ncdn
# GN=Atp6v1a
# GN=Eno2
# GN=Ap2a2
# GN=Atp6v1b2
# GN=Aldoa
# GN=Arhgef11
# GN=Cct3
# GN=Ap2a1
# GN=Grn
# GN=Igh
# GN=Stxbp1
# GN=EG433182
# GN=Tcp1
# ...

# %%
# import csv
# with open('/data/x.csv','w') as out:
#       csv_out=csv.writer(out)
#       csv_out.writerow(e)
#       for row in e:
#         csv_out.writerow(row)
